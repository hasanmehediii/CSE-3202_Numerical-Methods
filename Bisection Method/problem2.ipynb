# %% [markdown]
# Imports

# %%
import math
import matplotlib.pyplot as plt

# %% [markdown]
# Function Definition

# %%
def f(x):
    return 1-(400/(9.81*(3*x+(x**2)/2)**3)*(3+x))

# %% [markdown]
# Bisection Method Implementation

# %%
def bisection(a, b, tol):
    if f(a) * f(b) >= 0:
        print("Bisection method fails.")
        return 0

    print(f"Initial interval length L0 = {b-a}")
    print(f"{'Iter':<5}{'a':<15}{'b':<15}{'xr=(a+b)/2':<15}{'f(xr)':<20}{'εa (%)':<15}")
    print("-"*100)

    it = 0
    xr_old = a
    errors = []  
    num=0

    while it<=11:
        it += 1
        xr = (a + b) / 2

        if it == 1:
            continue
        else:
            ea = abs((xr - xr_old) / xr) * 100

        errors.append(ea) 
        num+=1
        print(f"{num:<5}"
              f"{a:<15.10f}{b:<15.10f}{xr:<15.10f}{f(xr):<20.10f}"
              f"{(f'{ea:.10f}')}"
              )
        
        if ea < tol:
            break

        if f(xr) == 0:
            break
        elif f(a) * f(xr) < 0:
            b = xr
        else:
            a = xr

        xr_old = xr
    
    plt.figure()
    plt.plot(range(1, len(errors)+1), errors, marker='o')
    plt.xlabel('Iteration')
    plt.ylabel('Absolute Error (%)')
    plt.title('Convergence of Absolute Error in Bisection Method')
    plt.grid(True)
    plt.show()

    return xr

# %% [markdown]
# Main Function

# %%
a, b = 0.5, 2.5
tol = 1

root = bisection(a, b, tol)
print(f"\nApproximate root: {root:.10f}\n")
# Out:
# Initial interval length L0 = 2.0
# Iter a              b              xr=(a+b)/2     f(xr)               εa (%)
# ----------------------------------------------------------------------------------------------------
# 1    0.5000000000   2.5000000000   1.5000000000   -0.0309459987       66.6666666667
# 2    1.5000000000   2.5000000000   2.0000000000   0.6018093782        25.0000000000
# 3    1.5000000000   2.0000000000   1.7500000000   0.3789088700        14.2857142857
# 4    1.5000000000   1.7500000000   1.6250000000   0.2069271765        7.6923076923
# 5    1.5000000000   1.6250000000   1.5625000000   0.0979562383        4.0000000000
# 6    1.5000000000   1.5625000000   1.5312500000   0.0362608605        2.0408163265
# 7    1.5000000000   1.5312500000   1.5156250000   0.0033830901        1.0309278351
# 8    1.5000000000   1.5156250000   1.5078125000   -0.0135951932       0.5181347150
# Approximate root: 1.5078125000
